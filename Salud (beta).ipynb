# %%
import pandas as pd
import plotly.graph_objects as go
import unidecode
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
from geopy import distance
import time
import math

# %%
defunciones = f'C:/Users/jcord/OneDrive/Escritorio/Codigos/Mapoteca/Salud/defunciones.csv'
#datos = pd.read_csv(defunciones, error_bad_lines=False)
#datos = pd.read_csv(defunciones, sep =";")
df = pd.read_csv(defunciones, sep=";")
#datos.head(20)
df.head(20)
#(pd.Dataframe(defunciones))
#df["new_column"] = df.apply(lambda row: unidecode.unidecode(row["GLOSA_COMUNA_RESIDENCIA"]), axis=1)
# Out:
#     ANO_DEF  FECHA_DEF GLOSA_SEXO  EDAD_TIPO  EDAD_CANT  \
# 0      2021  21/1/2021      Mujer          1         89
# 1      2021  18/6/2021     Hombre          1         90
# 2      2021  16/3/2021      Mujer          1         89
# 3      2021  19/3/2021      Mujer          1         93
# 4      2021   5/1/2021      Mujer          1         94
# 5      2021  19/5/2021      Mujer          1         95
# 6      2021  19/1/2021     Hombre          1         95
# 7      2021  24/5/2021     Hombre          1         97
# 8      2021   6/5/2021      Mujer          1         95
# 9      2021  21/3/2021     Hombre          1        111
# 10     2021   5/5/2021      Mujer          1         88
# 11     2021   8/5/2021     Hombre          1        116
# 12     2021  24/3/2021     Hombre          1         91
# 13     2021  22/1/2021     Hombre          1         96
# 14     2021  25/4/2021      Mujer          1         93
# 15     2021  16/1/2021     Hombre          1         89
# ...

# %%
##Crear objeto Nominatim
geo = Nominatim(user_agent="MyApp")

# %%
#Geocoficacion

loc = geo.geocode("GLOSA_COMUNA_RESIDENCIA")
print (loc)
print (loc.latitude,loc.longitude)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1df383de69a3> in <module>
#       3 loc = geo.geocode("GLOSA_COMUNA_RESIDENCIA")
#       4 print (loc)
# ----> 5 print (loc.latitude,loc.longitude)
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
from keplergl import KeplerGl
map_1 = KeplerGl()
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl()
