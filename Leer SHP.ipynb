# %%
#import geopandas as gpd

# %%
#pip install Geohash

# %%
#pip install descartes

# %%
import pandas as pd
import geopandas as gpd
import json

# %%
quinta_normal = f"C:/Users/jcord/OneDrive/Escritorio/Codigos/Mapoteca/PREDIOS/PREDIOS_STGO/CDSF_QUINTA_NORMAL_PREDIOS.shp"
comuna = gpd.read_file(quinta_normal)

# %%
comuna.plot()
# Out:
# <AxesSubplot:>
